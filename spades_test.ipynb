# %%
# %load_ext autoreload
# %autoreload 2
import rlcard

# %%
import sys
print(sys.executable)
from rlcard.agents import RandomAgent

# %%
config = {'allow_step_back': True, 'seed': 42}
env = rlcard.make('spades', config=config)

# Create random agents
agents = [RandomAgent(env.num_actions) for _ in range(env.num_players)]
env.set_agents(agents)

# Play a game
trajectories, payoffs = env.run(is_training=False)
# Out:
# Starting to deal cards
# All cards dealt
# Team scores: [34, 33]
# Starting to deal cards
# All cards dealt
# Team scores: [68, 37]
# Starting to deal cards
# All cards dealt
# Team scores: [28, 51]
# Starting to deal cards
# All cards dealt
# Team scores: [5, 45]
# Starting to deal cards
# All cards dealt
# Team scores: [20, 168]
# Starting to deal cards
# All cards dealt
# Team scores: [100, 146]
# Starting to deal cards
# All cards dealt
# Team scores: [105, 150]
# Starting to deal cards
# All cards dealt
# Team scores: [98, 157]
# Starting to deal cards
# All cards dealt
# Team scores: [72, 163]
# Starting to deal cards
# All cards dealt
# Team scores: [105, 188]
# Starting to deal cards
# All cards dealt
# Team scores: [108, 203]
# Starting to deal cards
# All cards dealt
# Team scores: [214, 241]
# Starting to deal cards
# All cards dealt
# Team scores: [217, 214]
# Starting to deal cards
# All cards dealt
# Team scores: [169, 257]
# Starting to deal cards
# All cards dealt
# Team scores: [201, 241]
# Starting to deal cards
# All cards dealt
# Team scores: [153, 278]
# Starting to deal cards
# All cards dealt
# Team scores: [139, 316]
# Starting to deal cards
# All cards dealt
# Team scores: [115, 297]
# Starting to deal cards
# All cards dealt
# Team scores: [148, 303]
# Starting to deal cards
# All cards dealt
# Team scores: [153, 307]
# Starting to deal cards
# All cards dealt
# Team scores: [140, 379]
# Starting to deal cards
# All cards dealt
# Team scores: [156, 371]
# Starting to deal cards
# All cards dealt
# Team scores: [150, 378]
# Starting to deal cards
# All cards dealt
# Team scores: [110, 397]
# Starting to deal cards
# All cards dealt
# Team scores: [113, 415]
# Starting to deal cards
# All cards dealt
# Team scores: [157, 408]
# Starting to deal cards
# All cards dealt
# Team scores: [223, 409]
# Starting to deal cards
# All cards dealt
# Team scores: [204, 381]
# Starting to deal cards
# All cards dealt
# Team scores: [198, 387]
# Starting to deal cards
# All cards dealt
# Team scores: [182, 393]
# Starting to deal cards
# All cards dealt
# Team scores: [142, 433]
# Starting to deal cards
# All cards dealt
# Team scores: [102, 407]
# Starting to deal cards
# All cards dealt
# Team scores: [127, 401]
# Starting to deal cards
# All cards dealt
# Team scores: [113, 415]
# Starting to deal cards
# All cards dealt
# Team scores: [73, 367]
# Starting to deal cards
# All cards dealt
# Team scores: [78, 361]
# Starting to deal cards
# All cards dealt
# Team scores: [94, 353]
# Starting to deal cards
# All cards dealt
# Team scores: [100, 356]
# Starting to deal cards
# All cards dealt
# Team scores: [160, 308]
# Starting to deal cards
# All cards dealt
# Team scores: [188, 309]
# Starting to deal cards
# All cards dealt
# Team scores: [148, 335]
# Starting to deal cards
# All cards dealt
# Team scores: [125, 431]
# Starting to deal cards
# All cards dealt
# Team scores: [205, 440]
# Starting to deal cards
# All cards dealt
# Team scores: [175, 470]
# Starting to deal cards
# All cards dealt
# Team scores: [206, 489]
# Starting to deal cards
# All cards dealt
# Team scores: [246, 528]
# Game ended: Player has no cards in hand
#
# Game Over!
# Final scores: [246, 528]
# Team 2 won by reaching 500!

# %%
print("Number of actions:", env.num_actions)
print("Number of players:", env.num_players)
print("Shape of state:", env.state_shape)
print("Shape of action:", env.action_shape)

# %%
agent = RandomAgent(num_actions=env.num_actions)
env.set_agents([agent for _ in range(env.num_players)])

# %%
trajectories, player_wins = env.run(is_training=False)

# %%
print(trajectories)

# %%
print(player_wins)
